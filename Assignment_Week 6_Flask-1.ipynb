# %% [markdown]
# ## Assignment Flask-1

# %% [markdown]
# #### Q1. What is Flask Framework? What are the advantages of Flask Framework?
#
# Flask is a lightweight Python web framework that provides useful tools and features for creating web applications in the Python Language. It gives developers flexibility and is an accessible framework for new developers because you can build a web application quickly using only a single Python file.
#
# 1. Pros of Flask
# - It is a lightweight framework that offers hassle-free development.
# - Provide flexibility to the developer to experiment with their modules or architecture.
# - It is suitable for small projects.
# - Offers a built-in development server and fast debugger.
# - Easily scalable for the applications.
# - Support for secure cookies.

# %% [markdown]
# #### Q2.Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %%
from flask import Flask

app = Flask(__name__)

@app.route('/')
def index():
    return 'Hello World!'

app.run(host='0.0.0.0', port=81)
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.1.102:81/ (Press CTRL+C to quit)
# 192.168.1.102 - - [13/Sep/2023 12:57:49] "GET / HTTP/1.1" 200 -

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Q3. What is App routing in Flask? Why do we use app routes?
# Ans - App routing is the technique used to map the specific URL with the associated function intended to perform some task. The Latest Web frameworks use the routing technique to help users remember application URLs. List the different methods to bind the URLs to their associated functions.

# %% [markdown]
# #### Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
# - Company Name: ABC Corporation
# - Location: India
# - Contact Detail: 999-999-9999

# %%
from flask import Flask

app = Flask(__name__)

@app.route('/')
def hello():
    return 'Welcome to ABC Corporation'

@app.route("/")
def index():
    return '- Company Name: ABC Corporation, - Location: India , - Contact Detail: 999-999-9999'
  
if __name__ == "__main__":
    app.run(host='0.0.0.0')
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.1.102:5000/ (Press CTRL+C to quit)
# 192.168.1.102 - - [13/Sep/2023 13:04:33] "GET / HTTP/1.1" 200 -
# 192.168.1.102 - - [13/Sep/2023 13:04:33] "GET /favicon.ico HTTP/1.1" 404 -
# 192.168.1.102 - - [13/Sep/2023 13:06:20] "GET /index HTTP/1.1" 404 -

# %%
from flask import Flask

app = Flask(__name__)


@app.route("/")
def root():
    return "Welcome to ABC Corporation"

@app.route("/hello")
def hello():
    return "- Company Name: ABC Corporation, - Location: India , - Contact Detail: 999-999-9999"


if __name__ == "__main__":
    app.run(host='0.0.0.0')
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.1.102:5000/ (Press CTRL+C to quit)
# 192.168.1.102 - - [13/Sep/2023 13:08:11] "GET / HTTP/1.1" 200 -
# 192.168.1.102 - - [13/Sep/2023 13:08:16] "GET /hello HTTP/1.1" 200 -
# 192.168.1.102 - - [13/Sep/2023 13:08:50] "GET / HTTP/1.1" 200 -

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.
#
# Ans - Flask url_for() method
# The url_for() method, is used to prepare a URL, for a function dynamically, such that, changing URLs, in the application, is avoided. It accepts, the name of the view function, as the first argument, and, any number of keywords, to be sent(to the view function), as the second argument.

# %%
from flask import *  
   
app = Flask(__name__)  
  
@app.route('/admin')  
def admin():  
    return 'admin'  
  
@app.route('/librarion')  
def librarion():  
    return 'librarion'  
  
@app.route('/student')  
def student():  
    return 'student'  
  
@app.route('/user/<name>')  
def user(name):  
    if name == 'admin':  
        return redirect(url_for('admin'))  
    if name == 'librarion':  
        return redirect(url_for('librarion'))  
    if name == 'student':  
        return redirect(url_for('student'))  
if __name__ =='__main__':  
    app.run(host='0.0.0.0')
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.1.102:5000/ (Press CTRL+C to quit)
# 192.168.1.102 - - [13/Sep/2023 13:45:37] "GET / HTTP/1.1" 404 -
# 192.168.1.102 - - [13/Sep/2023 13:45:47] "GET /admin HTTP/1.1" 200 -
# 192.168.1.102 - - [13/Sep/2023 13:45:57] "GET /student HTTP/1.1" 200 -

# %% [markdown]
# ![image.png](attachment:image.png)
